# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import osmnx as ox
from descartes import PolygonPatch
from shapely.geometry import Point, LineString, Polygon, MultiPolygon

# %%
# load yerevan city from openstreetmap using osmmnx api
city = ox.geocode_to_gdf("Nigeria", which_result=2)
print(city.crs)
city = ox.projection.project_gdf(city)
ax = city.plot(ec='none')
#_ = ax.axis('off')
print(city.crs)
# Out:
# epsg:4326
# +proj=utm +zone=31 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs

# %%
place = 'Portugal'
G = ox.geometries_from_place(place)
fig, ax = ox.plot_shape(G, figsize=(17,17))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 place = 'Portugal'
# ----> 2 G = ox.geometries_from_place(place)
#       3 fig, ax = ox.plot_shape(G, figsize=(17,17))
#
# TypeError: geometries_from_place() missing 1 required positional argument: 'tags'

# %%
exploded_gdf_place = gdf_place.explode()
exploded_gdf_place['area'] = exploded_gdf_place.area
exploded_gdf_place.sort_values(by='area', inplace=True)
smaller_area_Portugal= exploded_gdf_place.iloc[4]['geometry']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 exploded_gdf_place = gdf_place.explode()
#       2 exploded_gdf_place['area'] = exploded_gdf_place.area
#       3 exploded_gdf_place.sort_values(by='area', inplace=True)
#
# NameError: name 'gdf_place' is not defined
